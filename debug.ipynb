# %%
import numpy as np

import time
import sys

from matplotlib import pyplot as plt

# %% [markdown]
# # Let's debug!

# %%
from LPT.moment_expansion_fftw import MomentExpansion

# %%
# To match the plots in Chen, Vlah & White (2020) let's
# work at z=0.8, and scale our initial power spectrum
# to that redshift:
z,D,f      = 0.8,0.6819,0.8076
klin,plin  = np.loadtxt("pk.dat",unpack=True)
plin      *= D**2

# %%
# Initialize the class -- with no wisdom file passed it will
# experiment to find the fastest FFT algorithm for the system.
start= time.time()
mome = MomentExpansion(klin,plin,kmin=1e-3)
kl,p0,p2,p4 = mome.compute_redshift_space_power_multipoles(pars,f,reduced=True,apar=1.01,aperp=0.99)
print("Elapsed time: ",time.time()-start," seconds.")

print(np.sum(np.isnan(p2)))

plt.plot(kl, kl*p0)
plt.plot(kl, kl*p2)
plt.show()
# Out:
# Elapsed time:  1.2532060146331787  seconds.
# 0

# %%
for ii in range(500):
    start= time.time()
    mome = MomentExpansion(klin,plin,kmin=1e-3)
    kl,p0,p2,p4 = mome.compute_redshift_space_power_multipoles(pars,f,reduced=True,apar=1.01,aperp=0.99)
    print("Elapsed time: ",time.time()-start," seconds.")

    print(ii, p2[0])
# Out:
# Elapsed time:  1.5970938205718994  seconds.
# 0 5079.459863501298
# Elapsed time:  1.298171043395996  seconds.
# 1 5079.459863501298
# Elapsed time:  1.2399089336395264  seconds.
# 2 5079.459863501298
# Elapsed time:  1.3289060592651367  seconds.
# 3 5079.459863501298
# Elapsed time:  1.1976470947265625  seconds.
# 4 5079.459863501298
# Elapsed time:  1.2229609489440918  seconds.
# 5 5079.459863501298
# Elapsed time:  1.2839570045471191  seconds.
# 6 5079.459863501298
# Elapsed time:  1.2149288654327393  seconds.
# 7 5079.459863501298
# Elapsed time:  1.3762092590332031  seconds.
# 8 5079.459863501298
# Elapsed time:  1.222074270248413  seconds.
# 9 5079.459863501298
# Elapsed time:  1.2335829734802246  seconds.
# 10 5079.459863501298
# Elapsed time:  1.2877318859100342  seconds.
# 11 5079.459863501298
# Elapsed time:  1.8727748394012451  seconds.
# 12 5079.459863501298
# Elapsed time:  1.7640759944915771  seconds.
# 13 5079.459863501298
# Elapsed time:  1.918382167816162  seconds.
# 14 5079.459863501298
# Elapsed time:  1.290546178817749  seconds.
# 15 5079.459863501298
# Elapsed time:  1.1610512733459473  seconds.
# 16 5079.459863501298
# Elapsed time:  1.1573257446289062  seconds.
# 17 5079.459863501298
# Elapsed time:  1.14453125  seconds.
# 18 5079.459863501298
# Elapsed time:  1.1554739475250244  seconds.
# 19 5079.459863501298
# Elapsed time:  1.2665050029754639  seconds.
# 20 5079.459863501298
# Elapsed time:  1.3755180835723877  seconds.
# 21 5079.459863501298
# Elapsed time:  1.2246270179748535  seconds.
# 22 5079.459863501298
# Elapsed time:  1.2654750347137451  seconds.
# 23 5079.459863501298
# Elapsed time:  1.2659151554107666  seconds.
# 24 5079.459863501298
# Elapsed time:  1.2846720218658447  seconds.
# 25 5079.459863501298
# Elapsed time:  1.2957308292388916  seconds.
# 26 5079.459863501298
# Elapsed time:  1.1921532154083252  seconds.
# 251 5079.459863501298
# Elapsed time:  1.1942839622497559  seconds.
# 252 5079.459863501298
# Elapsed time:  1.3551089763641357  seconds.
# 253 5079.459863501298
# Elapsed time:  1.2447547912597656  seconds.
# 254 5079.459863501298
# Elapsed time:  1.2667787075042725  seconds.
# 255 5079.459863501298
# Elapsed time:  1.2735378742218018  seconds.
# 256 5079.459863501298
# Elapsed time:  1.2543690204620361  seconds.
# 257 5079.459863501298
# Elapsed time:  1.202955961227417  seconds.
# 258 5079.459863501298
# Elapsed time:  1.2496538162231445  seconds.
# 259 5079.459863501298
# Elapsed time:  1.2485730648040771  seconds.
# 260 5079.459863501298
# Elapsed time:  1.597182035446167  seconds.
# 261 5079.459863501298
# Elapsed time:  1.4346799850463867  seconds.
# 262 5079.459863501298
# Elapsed time:  1.6950321197509766  seconds.
# 263 5079.459863501298
# Elapsed time:  1.7375431060791016  seconds.
# 264 5079.459863501298
# Elapsed time:  1.4986109733581543  seconds.
# 265 5079.459863501298
# Elapsed time:  2.182758092880249  seconds.
# 266 5079.459863501298
# Elapsed time:  2.4757421016693115  seconds.
# 267 5079.459863501298
# Elapsed time:  1.4407198429107666  seconds.
# 268 5079.459863501298
# Elapsed time:  1.2619171142578125  seconds.
# 269 5079.459863501298
# Elapsed time:  1.4339439868927002  seconds.
# 270 5079.459863501298
# Elapsed time:  1.412761926651001  seconds.
# 271 5079.459863501298
# Elapsed time:  1.7723746299743652  seconds.
# 272 5079.459863501298
# Elapsed time:  1.6056771278381348  seconds.
# 273 5079.459863501298
# Elapsed time:  1.5562942028045654  seconds.
# 274 5079.459863501298
# Elapsed time:  1.366361141204834  seconds.
# 275 5079.459863501298
# Elapsed time:  1.3742101192474365  seconds.
# 276 5079.459863501298
# Elapsed time:  1.6528377532958984  seconds.
# 277 5079.459863501298
# Elapsed time:  1.801814079284668  seconds.
# 278 5079.459863501298
# Elapsed time:  1.3304111957550049  seconds.
# 279 5079.459863501298
# Elapsed time:  1.2689926624298096  seconds.
# 280 5079.459863501298
# Elapsed time:  1.8481218814849854  seconds.
# 281 5079.459863501298
# Elapsed time:  1.4856557846069336  seconds.
# 282 5079.459863501298
# Elapsed time:  1.4681799411773682  seconds.
# 283 5079.459863501298
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-7e0155243630> in <module>()
#       1 for ii in range(500):
#       2     start= time.time()
# ----> 3     mome = MomentExpansion(klin,plin,kmin=1e-3)
#       4     kl,p0,p2,p4 = mome.compute_redshift_space_power_multipoles(pars,f,reduced=True,apar=1.01,aperp=0.99)
#       5     print("Elapsed time: ",time.time()-start," seconds.")
#
# ~/Work/velocileptors/LPT/moment_expansion_fftw.py in __init__(self, kmin, kmax, nk, *args, **kw)
#      42
#      43     def setup_velocity_moments(self):
# ---> 44         self.make_ptable(kmin = self.kmin, kmax = self.kmax, nk = self.nk)
#      45         self.make_vtable(kmin = self.kmin, kmax = self.kmax, nk = self.nk)
#      46         self.make_spartable(kmin = self.kmin, kmax = self.kmax, nk = self.nk)
#
# ~/Work/velocileptors/LPT/moment_expansion_fftw.py in setup_velocity_moments(self)
#      45         self.make_vtable(kmin = self.kmin, kmax = self.kmax, nk = self.nk)
#      46         self.make_spartable(kmin = self.kmin, kmax = self.kmax, nk = self.nk)
# ---> 47         self.make_stracetable(kmin = self.kmin, kmax = self.kmax, nk = self.nk)
#      48         self.convert_sigma_bases(basis='Polynomial')
#      49
#
# ~/Work/velocileptors/LPT/cleft_fftw.py in make_ptable(self, kmin, kmax, nk)
#     179         self.pktable[:, 0] = kv[:]
#     180         for foo in range(nk):
# --> 181             self.pktable[foo, 1:] = self.p_integrals(kv[foo])
#     182
#     183     def combine_bias_terms_pk(self, b1, b2, bs, b3, alpha, sn):
#
# ~/Work/velocileptors/LPT/cleft_fftw.py in p_integrals(self, k)
#     161
#     162             # do FFTLog
# --> 163             ktemps, bias_ffts = self.sph.sph(l, bias_integrands)
#     164             ret +=  k**l * interp1d(ktemps, bias_ffts)(k)
#     165
#
# ~/Work/velocileptors/Utils/spherical_bessel_transform_fftw.py in sph(self, nu, fq)
#      95         fks = self.fft_object()
#      96         self.fks[:] = np.conj(fks * self.udict[nu])
# ---> 97         gs = self.ifft_object()
#      98
#      99         return y, gs[:,self.ii_l:self.ii_r] * y**(-q)
#
# KeyboardInterrupt:

# %%
a
# Out:
# (b'(fftw-3.3.8 fftw_wisdom #x3c273403 #x192df114 #x4d08727c #xe98e9b9d\n  (fftw_codelet_r2cfII_2 2 #x11bdd #x11bdd #x0 #xfcde69de #xb320f2f0 #xf9c513b9 #x0388aa6b)\n  (fftw_rdft2_vrank_geq1_register 0 #x11bdd #x11bdd #x0 #x44f923db #xd3dff737 #xd2791850 #xd8730d16)\n  (fftw_codelet_t1fv_64_avx 0 #x11bdd #x11bdd #x0 #x52d2c729 #xd90ebce1 #x6bd78c14 #x22b31d6d)\n  (fftw_rdft2_vrank_geq1_register 0 #x11bdd #x11bdd #x0 #x6c566db4 #x3b100e08 #xaefc937d #x9b1528a7)\n  (fftw_codelet_hc2cbdftv_2_avx 0 #x10bdd #x10bdd #x0 #x48973cb4 #x08442929 #xc06ecb0d #xaa8b176e)\n  (fftw_rdft2_vrank_geq1_register 0 #x11bdd #x11bdd #x0 #x5cf43de3 #xf214fa37 #x650c4cbe #x67103a79)\n  (fftw_codelet_n2fv_32_avx 0 #x11bdd #x11bdd #x0 #xdee5c0e8 #x7295d10d #x5970984f #x55f6d050)\n  (fftw_rdft2_vrank_geq1_register 0 #x11bdd #x11bdd #x0 #x7a4d9d3f #x77b7e52b #x14fbd8ee #x1d7c110e)\n  (fftw_codelet_r2cf_2 2 #x11bdd #x11bdd #x0 #x96022fcd #x29ef0675 #x1b46036f #x81e6cbd5)\n  (fftw_codelet_n2bv_64_avx 0 #x10bdd #x10bdd #x0 #xc764abd9 #x052ddde0 #x8d0b0a6b #xba62ce71)\n  (fftw_rdft2_nop_register 0 #x11bdd #x11bdd #x0 #x468f831e #xf3ef0f03 #x2e3af8be #x49e859e1)\n  (fftw_codelet_t1bv_32_avx 0 #x10bdd #x10bdd #x0 #x02856f13 #x0254c9df #xb06cab08 #x3d92c895)\n  (fftw_rdft2_vrank_geq1_register 0 #x11bdd #x11bdd #x0 #x2b0b45f3 #x5eed1d52 #x150d7627 #xaa328d5e)\n  (fftw_codelet_hc2cfdftv_2_avx 0 #x11bdd #x11bdd #x0 #xdc38cc14 #x0d1c6e3c #xc0ae48bf #xa0e0eb5a)\n  (fftw_codelet_r2cbIII_2 2 #x10bdd #x10bdd #x0 #xcce019d6 #x26983d8d #xbc101cef #xc1423dd4)\n  (fftw_rdft_rank0_register 2 #x11bdd #x11bdd #x0 #xe31554e8 #x3d4840be #x70ca63fa #x1f75d57c)\n  (fftw_codelet_r2cb_2 2 #x10bdd #x10bdd #x0 #x42fdf325 #xd7e601c1 #xfc8652bf #x646be564)\n  (fftw_rdft2_buffered_register 0 #x11bdd #x11bdd #x0 #x48973cb4 #x08442929 #xc06ecb0d #xaa8b176e)\n  (fftw_dft_r2hc_register 0 #x11bdd #x11bdd #x0 #xd65a78e2 #x9136c993 #x0817dded #xe7b7810e)\n  (fftw_rdft2_vrank_geq1_register 0 #x11bdd #x11bdd #x0 #xabf89012 #x3198ca31 #x5dc9d799 #x071fae6b)\n)\n',
#  b'(fftw-3.3.8 fftwf_wisdom #x706526c0 #x2f8b6c85 #x8cd1bb1a #x7c96e03d\n)\n',
#  b'(fftw-3.3.8 fftwl_wisdom #x0821b5c7 #xa4c07d5a #x21b58211 #xebe513ab\n)\n')

# %% [markdown]
# We'll start with how to compute $P(k,\mu)$ given a linear theory $P(k)$ file:

# %%
# Set up some fiducial values for the parameters -- we'll use the
# examples from the paper and we'll used the "reduced" parameter set:
# pars: the biases and counter terms.
#    b1,b2,bs, b3: linear, quadratic & cubic parameters
#    alpha0,alpha2,alpha4: counterterms
#    sn,s0: stochastic contributions to P(k) and sigma^2.
biases = [0.70,0.5,-0.3,0.0]
cterms = [10.0,20.,-60.]
stoch  = [1800.,-1000.]
pars   = biases + cterms + stoch
#
# Compute the wedges, here we'll just to a single mu.  Note if we
# just wanted the real-space power spectrum we could pass mu=0 to
# compute_redshift_space_power_at_mu.  Here we'll do mu=0.5:
mu     = 0.5
start  = time.time()
kw,pkw = mome.compute_redshift_space_power_at_mu(pars,f,mu,reduced=True)
print("Elapsed time: ",time.time()-start," seconds.")
# Out:
# Elapsed time:  0.2467951774597168  seconds.

# %%
print("# First few k bins for mu=",mu)
print("# {:>10s} {:>12s}".format("k","P(k,mu)"))
for k,p in zip(kw[:10],pkw[:10]):
    print("{:12.4e} {:12.4e}".format(k,p))

# %% [markdown]
# And now let's look at the (even) multipoles, $P_{\ell}(k)$:

# %%
# It's about as easy to compute the multipole moments up to ell=4:
start       = time.time()
kl,p0,p2,p4 = mome.compute_redshift_space_power_multipoles(pars,f,reduced=True)
print("Elapsed time: ",time.time()-start," seconds.")

# %%
print("# First few k bins for multipoles")
print("# {:>10s} {:>12s} {:>12s} {:>12s}".format("k","P0","P2","P4"))
for k,mono,quad,hexa in zip(kl[:10],p0[:10],p2[:10],p4[:10]):
    print("{:12.4e} {:12.4e} {:12.4e} {:12.4e}".format(k,mono,quad,hexa))

# %% [markdown]
# ### Advanced options ###
#
# Now we can start looking at the various options to the code, and how to use a broader set of parameters to investigate more statistics:

# %%
# Run the moment expansion!
from LPT.moment_expansion_fftw import MomentExpansion

# we scale the z = 0 power spectrum given to give z = 0.8 results
z, D, f = 0.8, 0.6819, 0.8076
k, p = np.loadtxt('pk.dat').T

t1 = time.time()
moments = MomentExpansion(k, D**2 * p, beyond_gauss = False, one_loop= True, import_wisdom=True, wisdom_file='./wisdom.npy',\
                        kmin = 1e-2, kmax = 0.5, nk = 50,
                        cutoff=10, extrap_min = -4, extrap_max = 3, N = 2000, threads=1, jn=5, shear=True)
t2 = time.time()
print(t2-t1)

# %%
# this saves a file called "wisdom.npy" that speeds up fftw if running for first time
moments.export_wisdom('./wisdom.npy')

# %%
# Extract the Velocity Statistics First for a sample set of bias parameters
# Parameters chosen to match the plots in the paper.

# These are, in order
# b1, b2, bs, b3: linear quadratic parameters
# alpha, alphav, alpha_s0, alpha_s2: one-loop counterterms for each component of the velocity moments
# sn, sv, s0: stochastic contributions to power spectrum, 1st, and 2nd moments


pars = [0.70, -1.3, -0.06, 0,  7.4, -17., 8.9, 3.1, 1.9e3, -4.2e3, -670]
b1, b2, bs, b3, alpha, alpha_v, alpha_s0, alpha_s2, sn, sv, s0 = pars

# %%
# The (real space) power spectrum:
kv, pth = moments.combine_bias_terms_pk(b1, b2, bs, b3, alpha, sn)
plt.semilogx( kv, kv * pth,label=r'LPT' )

plt.legend()
plt.xscale('linear')

plt.xlim(0,0.25)
plt.ylim(850,1120)

plt.ylabel(r'k P(k) [h$^{-2}$ Mpc$^2$]')
plt.xlabel('k [h/Mpc]')
plt.show()

# %%
# the 1st pairwise velocity moment
kv, vth = moments.combine_bias_terms_vk(b1, b2, bs, b3, alpha_v, sv)
plt.semilogx( kv, -f*kv**2 * vth )

kv, vth = moments.combine_bias_terms_vk(b1, 0, 0, 0, 0, 0)
plt.semilogx( kv, -f*kv**2 * vth, label=r'$b_1$' )

kv, vth = moments.combine_bias_terms_vk(b1, b2, bs, b3, 0, 0)
plt.semilogx( kv, -f*kv**2 * vth, label=r'$b_2, b_s$' )

kv, vth = moments.combine_bias_terms_vk(b1, b2, bs, b3, alpha_v, 0)
plt.semilogx( kv, -f*kv**2 * vth, label=r'+ c.t.' )


plt.legend(loc='upper right')
plt.ylabel(r'k$^2$ v(k) [h$^{-2}$ Mpc$^2$]')

plt.xscale('linear')
plt.xlim(0,0.25)
plt.ylim(400,950)

plt.xlabel('k [h/Mpc]')
plt.show()

# %%
# the 2nd pairwise velocity moment, monopole
# Note that the default basis is polynomial in mu for rsd convenience
# but for velocities only better to look at Legendre (multipole) basis

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, b2, bs, b3, alpha_s0, alpha_s2, s0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s0th )

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, 0, 0, 0, 0, 0, 0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s0th, label=r'$b_1$' )

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, b2, bs, b3, 0, 0, 0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s0th, label=r'$b_2, b_s, b_3$' )

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, b2, bs, b3, alpha_s0, alpha_s2, 0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s0th, label=r'+ c.t.' )


plt.legend(loc='upper right')
plt.ylabel(r'k$^3$ $\sigma_0$(k) [h$^{-2}$ Mpc$^2$]')

plt.xscale('linear')
plt.xlim(0,0.25)
plt.ylim(-120,180)

plt.xlabel('k [h/Mpc]')
plt.show()

# %%
# the 2nd pairwise velocity moment, quadrupole
kv, s0th, s2th = moments.combine_bias_terms_sk(b1, b2, bs, b3, alpha_s0, alpha_s2, s0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s2th )

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, 0, 0, 0, 0, 0, 0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s2th, label=r'$b_1$' )

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, b2, bs, b3, 0, 0, 0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s2th, label=r'$b_2, b_s$' )

kv, s0th, s2th = moments.combine_bias_terms_sk(b1, b2, bs, b3, alpha_s0, alpha_s2, 0, basis='Legendre')
plt.semilogx( kv, f**2*kv**3 * s2th, label=r'+ c.t.' )


plt.legend(loc='upper right')
plt.ylabel(r'k$^3$ $\sigma_0$(k) [h$^{-2}$ Mpc$^2$]')

plt.xscale('linear')
plt.xlim(0,0.25)
plt.ylim(-500,0)

plt.xlabel('k [h/Mpc]')
plt.show()

# %%
# Now combine into wedges via the moment expansion
plt.figure(figsize=(8,5))

mus = [0.1, 0.3, 0.5, 0.7, 0.9]


for ii, mu in enumerate(mus):
    
    # The c3 parameter is the counterterm ansatz to the third moment
    # Note that c3 enters as c3 / 6 * k^2 mu^4 P(k)
    kw, pw = moments.compute_redshift_space_power_at_mu(pars,f,mu,counterterm_c3=-120)
    plt.plot(kw, kw*pw,'C'+str(ii)+'-',label=r'$\mu = %.1f$'%(mu))
    
    kw, pw = moments.compute_redshift_space_power_at_mu(pars,f,mu,counterterm_c3=0)
    plt.plot(kw, kw*pw,'C'+str(ii)+'--')

plt.plot(kw, -1000*kw, 'k--', label='n = 2')    
    
plt.ylabel(r'$k P(k,\mu)$ [(Mpc/h)$^2$]')


plt.xlim(0,0.25)
plt.ylim(500,2000)

plt.legend(ncol=3,loc='lower right')



plt.show()

# %%
# ... and multipoles
plt.figure(figsize=(8,5))

ks, p0g, p2g, p4g = moments.compute_redshift_space_power_multipoles(pars,f,counterterm_c3=-120)
ks, p0, p2, p4 = moments.compute_redshift_space_power_multipoles(pars,f,counterterm_c3=0)

plt.plot(ks, -1000*ks,'k--',label='n=2')
plt.plot(ks, -1000*ks,'k-',label='+ c.t.')


plt.plot(ks, ks*p0,'C0-',label=r'$\ell = 0$')
plt.plot(ks, ks*p0g,'C0--')

plt.plot(ks, ks*p2,'C1-',label=r'$\ell = 2$')
plt.plot(ks, ks*p2g,'C1--')

plt.plot(ks, ks*p4,'C2-',label=r'$\ell = 4$')
plt.plot(ks, ks*p4g,'C2--')

plt.xlabel('k [h/Mpc]')
plt.ylabel(r'$k P_\ell(k)$ [(Mpc/h)$^2$]')

plt.xlim(0,0.25)
plt.ylim(0,1600)

plt.legend(ncol=3,loc='upper right')

plt.show()

# %%
# Note that we can also enter a more reduced set of parameters using the "reduced" keyword
# These are:
# the bias parameters b1, b2, bs
# the counterterms alpha0, alpha2, alpha4,
# and the stochastic contributions sn, s0
# In this case the "counterterm_c3" parameters is unused because it is subsumed by alpha4

# As an example let's take:
pars = [0.7, 0.5, -0.3, 0, 10, 20, -60, 1800, -1000]

# Now combine into wedges via the moment expansion...
# Compared here to Kaiser x Real Space P(k), which is very different!

plt.figure(figsize=(8,5))

mus = [0.1, 0.3, 0.5, 0.7, 0.9]


for ii, mu in enumerate(mus):
    
    kw, pw = moments.compute_redshift_space_power_at_mu(pars,f,mu,reduced=True)
    plt.plot(kw, kw*pw,'C'+str(ii)+'-',label=r'$\mu = %.1f$'%(mu))
    
    kw, pw = moments.compute_redshift_space_power_at_mu(pars,f,0,reduced=True)
    plt.plot(kw, kw *( (1 + pars[0] + f*mu**2)**2 / (1 + pars[0])**2 * (pw-pars[7]) + pars[7]),'C'+str(ii)+'--')
    
plt.plot(kw, -1000*kw, 'k--',label='Kaiser')
plt.ylabel(r'$k P(k,\mu)$ [(Mpc/h)$^2$]')


plt.xlim(0,0.25)
plt.ylim(500,2100)

plt.legend(ncol=3,loc='lower right')



plt.show()

# %%
# and similarly for multipoles:

plt.figure(figsize=(8,5))

ks, p0, p2, p4 = moments.compute_redshift_space_power_multipoles(pars,f,reduced=True)


plt.plot(ks, ks*p0,'C0-',label=r'$\ell = 0$')

plt.plot(ks, ks*p2,'C1-',label=r'$\ell = 2$')

plt.plot(ks, ks*p4,'C2-',label=r'$\ell = 4$')

plt.xlabel('k [h/Mpc]')
plt.ylabel(r'$k P_\ell(k)$ [(Mpc/h)$^2$]')

plt.xlim(0,0.25)
plt.ylim(0,1600)

plt.legend(ncol=3,loc='upper right')

plt.show()

# %%
# Finally, we can add in the AP effect:

# As an example let's take:
apar, aperp = 2, 1
pars = [0.7, 0.5, -0.3, 0, 10, 20, -60, 1800, -1000]

# Now combine into wedges via the moment expansion...
# Compared here to Kaiser x Real Space P(k), which is very different!

plt.figure(figsize=(8,5))

mus = [0, 0.5, 1]


for ii, mu in enumerate(mus):
    
    kw, pw = moments.compute_redshift_space_power_at_mu(pars,f,mu,reduced=True)
    plt.plot(kw, pw,'C'+str(ii)+'-',label=r'$\mu = %.1f$'%(mu))
    
    kw, pw = moments.compute_redshift_space_power_at_mu(pars,f,mu,reduced=True,apar=apar,aperp=aperp)
    plt.plot(kw, pw ,'C'+str(ii)+'--')
    
plt.plot(kw, -1000*kw, 'k--',label='AP')
plt.ylabel(r'$P(k,\mu)$ [(Mpc/h)$^3$]')

plt.xscale('log')
plt.yscale('log')

plt.xlim(0.005,0.5)
plt.ylim(3000,100000)

plt.legend(ncol=3,loc='upper right')



plt.show()

# %%
pw
