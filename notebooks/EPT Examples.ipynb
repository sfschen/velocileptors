# %%
import numpy as np
import time
import sys

from matplotlib import pyplot as plt

# %% [markdown]
# ### Moment Expansion in EPT ###
#
# The velocileptors code can do calculations using the two most common flavors of perturbation theory: Lagrangian perturbation theory (LPT) and Eulerian perturbation theory (EPT).  In this notebook we demonstrate how to do the basic EPT calculations and some enhancements. Let's start with the moment expansion and its building blocks before turning to improved models and convenience functions.
#
# An important difference between the EPT and LPT calculations is that the former requires us to input a "no-wiggle" version of the linear power spectrum, plotted below. This is included in the class as a keyword pnw, which if set to none defaults to a Savitsky-Golay filtered input linear power spectrum. However, we have found that the wiggle/no-wiggle split is cleaner if you first divide out the Eisenstein and Hu ansatz, which we leave to the user as it is cosmology dependent.

# %%
# Run the basic EPT class:
from velocileptors.EPT.moment_expansion_fftw import MomentExpansion

# we scale the z = 0 power spectrum given to give z = 0.8 results
z, D, f = 0.8, 0.6819, 0.8076
k, p = np.loadtxt('pk.txt').T
#
# You can use our pre-compute P_{nw}:
# knw, pnw = np.loadtxt('pnw.txt').T
#
# or the discrete spectral method for the wiggle/no-wiggle split,
# described in Appendix D of arXiv:1810.02800, and provided
# through "pnw_dst" as part of velocileptors:
from velocileptors.Utils.pnw_dst import pnw_dst
_,pnw = pnw_dst(k,p)

plt.plot(k, k*p, label=r'$P_L$')
plt.plot(k, k*pnw, label=r'$P_{L,nw}$')
plt.legend()
plt.xlim(1e-3, 0.5)
plt.xlabel('k [h/Mpc]')
plt.ylabel(r'k P(k) [(Mpc/h)$^2$]')
plt.show()

# %% [markdown]
# The EPT calculation is very fast and does not depend on the number of points nk evaluated (here set to nk = 100).  Later we will see how to make this even faster!

# %%
start = time.time()
mome = MomentExpansion(k, D**2*p, pnw=D**2*pnw, kmin = 5e-3, kmax = 0.25, nk = 100,\
                       beyond_gauss=True, one_loop= True, third_order = True,\
                       N = 2000, extrap_min=-6, extrap_max=2, cutoff = 100, threads=1)
end = time.time()
print(end-start)
# Out:
# 1.0006089210510254

# %% [markdown]
# We can use this to compute the various velocity moments in EPT

# %%
# Default parameters for the halo plots in Chen, Vlah and White (2020)
sn, sv, s0 = 1380, 3800,  7122
b1, b2, bs, b3 = 1.68593608, -1.17, -0.715, -0.479
alpha, alphav, alpha0, alpha2 = 16.9, -10.8, 21.0, 5.40

# %%
pth = mome.combine_bias_terms_pk(b1,b2,bs,b3,alpha,sn) #pept_func(kdat, sn, b1, b2, bs, b3, alpha )
plt.plot( mome.kv, mome.kv * pth,label=r'EPT' )

#plt.plot(ept.ept.kint, ept.ept.kint* (b1**2 * ept.ept.pint + sn) )
plt.legend()

plt.xlim(0,0.25)
plt.ylim(750,1150)

plt.ylabel(r'k P(k) [h$^{-2}$ Mpc$^2$]')
plt.show()

# %%
vth = mome.combine_bias_terms_vk(b1,b2,bs,b3,alphav,sv)
plt.plot(mome.kv, -f * mome.kv**2 * vth)


plt.ylabel(r'k$^2$ v(k) [h$^{-2}$ Mpc$^2$]')
plt.xlim(0,0.25)
plt.ylim(400,950)
plt.xlabel('k [h/Mpc]')
plt.show()

# %%
s0th, s2th = mome.combine_bias_terms_sk(b1,b2,bs,b3,alpha0,alpha2,s0)
plt.plot(mome.kv, f**2 * mome.kv**3 * s0th)

plt.ylabel(r'k$^3 \sigma_0(k)\quad$ [h$^{-2}$ Mpc$^2$]')
plt.xlim(0,0.25)
plt.ylim(-120,180)
plt.xlabel('k [h/Mpc]')
plt.show()

# %%
plt.plot(mome.kv, f**2 * mome.kv**3 * s2th)

plt.ylabel(r'k$^3 \sigma_2(k)\quad$ [h$^{-2}$ Mpc$^2$]')
plt.xlim(0,0.25)
plt.ylim(-500,0)
plt.xlabel('k [h/Mpc]')
plt.show()

# %% [markdown]
# These components can be combined into the power spectrum:

# %%
# Now combine into wedges via the moment expansion
plt.figure(figsize=(8,5))

mus = [0.1, 0.3, 0.5, 0.7, 0.9]

for ii, mu in enumerate(mus):
    
    # The c3 parameter is the counterterm ansatz to the third moment
    # Note that c3 enters as c3 / 6 * k^2 mu^4 P(k)
    
    pars = [b1,b2,bs,b3,alpha,alphav,alpha0,alpha2,sn,sv,s0]
    
    kw, pw = mome.compute_redshift_space_power_at_mu(pars,f,mu, counterterm_c3 = -6*10/D**2, beyond_gauss=False,reduced=False)
    plt.plot(kw, kw*pw,'C'+str(ii)+'-',label=r'$\mu = %.1f$'%(mu))
    
    kkw, pw = mome.compute_redshift_space_power_at_mu(pars,f,mu, counterterm_c3 = 0, beyond_gauss=False,reduced=False)
    plt.plot(kw, kw*pw,'C'+str(ii)+'--')

plt.plot(kw, -1000*kw, 'k--', label='n = 2')    
    
plt.ylabel(r'$k P(k,\mu)$ [(Mpc/h)$^2$]')


plt.xlim(0,0.25)
plt.ylim(500,2000)

plt.legend(ncol=3,loc='lower right')

plt.xlim(0.03,0.25)
plt.ylim(700,2000)



plt.show()

# %%
# ... and multipoles
plt.figure(figsize=(8,5))

ks, p0g, p2g, p4g = mome.compute_redshift_space_power_multipoles(pars,f,counterterm_c3=0)
ks, p0, p2, p4 = mome.compute_redshift_space_power_multipoles(pars,f,counterterm_c3=-6*10/D**2)

plt.plot(ks, -1000*ks,'k--',label='n=2')
plt.plot(ks, -1000*ks,'k-',label='+ c.t.')


plt.plot(ks, ks*p0,'C0-',label=r'$\ell = 0$')
plt.plot(ks, ks*p0g,'C0--')

plt.plot(ks, ks*p2,'C1-',label=r'$\ell = 2$')
plt.plot(ks, ks*p2g,'C1--')

plt.plot(ks, ks*p4,'C2-',label=r'$\ell = 4$')
plt.plot(ks, ks*p4g,'C2--')

plt.xlabel('k [h/Mpc]')
plt.ylabel(r'$k P_\ell(k)$ [(Mpc/h)$^2$]')

plt.xlim(0,0.25)
plt.ylim(0,1600)

plt.legend(ncol=3,loc='upper right')

plt.show()

# %% [markdown]
# ### Direct Evaluation of the One-Loop Redshift-Space Power Spectrum ###
#
# We can also take an extra step and resum contributions from bulk velocities. This gives the "full IR-resummed" power spectrum in EPT, whereas summing up real-space moments naturally only resums the displacements.  This is a more accurate model, and is likely the one you would tend to use to fit data, so we provide a special class for it (```REPT``` for "resummed EPT").  Here we can compare it to the moment expansion model above.

# %%
# Can also use compute the 1-loop P(k,mu) directly:
# note third_order is not a keyword in this class since it is always on
from velocileptors.EPT.ept_fullresum_fftw import REPT

# %% [markdown]
# Here we set beyond_gauss = True so that the third and fourth moments are included, since they are necessarily present in the direct one-loop calculation.

# %%
start = time.time()
ept = REPT(k, D**2*p, pnw=D**2*pnw, kmin = 5e-3, kmax = 0.25, nk = 100,\
           beyond_gauss=True, one_loop= True,\
           N = 2000, extrap_min=-6, extrap_max=2, cutoff = 100, threads=1)

end = time.time()
print(end-start)
# Out:
# 0.1775045394897461

# %% [markdown]
# Let's see how it compares to the moment expansion.

# %%
# Compare with moment expansion:
b1, b2, bs, b3 = 1.68593608, -1.17, -0.715, -0.479
sn, sn2, sn4 = 0, 0, 0
alpha0, alpha2, alpha4, alpha6 = 0,0,0,0
pars = [b1, b2, bs, b3, alpha0, alpha2, alpha4, alpha6, sn, sn2, sn4]

# %%
plt.figure(figsize=(8,5))

mus = [0.1, 0.3, 0.5, 0.7, 0.9]


for ii, mu in enumerate(mus):
    
    kw, pw = ept.compute_redshift_space_power_at_mu(pars,f,mu)
    plt.plot(kw, kw*pw,'C'+str(ii)+'-',label=r'$\mu = %.1f$'%(mu))
    
    kw, pw = mome.compute_redshift_space_power_at_mu(pars,f,mu,beyond_gauss=True)
    plt.plot(kw, kw*pw,'C'+str(ii)+'--')



plt.plot(kw, -1000*kw, 'k--',label='ME')
plt.ylabel(r'$k P(k,\mu)$ [(Mpc/h)$^2$]')
plt.xlabel(r'k [h/Mpc]')


plt.xlim(0,0.25)
plt.ylim(400,1900)

plt.legend(ncol=3,loc='upper right')



plt.show()

# %% [markdown]
#  The differences in the wiggles are most noticeable in the highest mu in, as one might expect. Note that there is a large contribution from one-loop wiggles.

# %%
# ... and multipoles
plt.figure(figsize=(8,5))

ks, p0g, p2g, p4g = mome.compute_redshift_space_power_multipoles(pars,f,beyond_gauss=True,reduced=True)
ks, p0, p2, p4 = ept.compute_redshift_space_power_multipoles(pars,f)


plt.plot(ks, -1000*ks,'k-',label='ME')
plt.plot(ks, -1000*ks,'k--',label='Full')


plt.plot(ks, ks*p0,'C0-',label=r'$\ell = 0$')
plt.plot(ks, ks*p0g,'C0--')

plt.plot(ks, ks*p2,'C1-',label=r'$\ell = 2$')
plt.plot(ks, ks*p2g,'C1--')

plt.plot(ks, ks*p4,'C2-',label=r'$\ell = 4$')
plt.plot(ks, ks*p4g,'C2--')

plt.xlabel('k [h/Mpc]')
plt.ylabel(r'$k P_\ell(k)$ [(Mpc/h)$^2$]')

plt.xlim(0,0.25)
plt.ylim(0,1400)

plt.legend(ncol=3,loc='upper right')

plt.show()

# %% [markdown]
# ## Module With Varying D(z)
#
# Finally we show how to include a common time-saving feature available with the ```REPT``` code -- computing multiple redshifts at once.
#
# It is not uncommon that one wishes to compute PT predictions for a number of different samples at different redshifts but the same cosmology.  In this case the mode-coupling integrals only need to be (internally) computed once and can then be rescaled almost instantly.  The "cost" of computing multiple redshift bins is then essentially the same as computing a single bin.
#
# The functionality to do this is included within ```REPTDz```, which is almost the same as ```REPT```, discussed above.

# %%
from velocileptors.EPT.ept_fullresum_varyDz_fftw import REPT as REPTDz

# %%
start = time.time()
eptdz = REPTDz(k, p, pnw=pnw, kmin = 5e-3, kmax = 0.25, nk = 100,\
           beyond_gauss=True, one_loop= True,\
           N = 2000, extrap_min=-6, extrap_max=2, cutoff = 100, threads=1)
end = time.time()
print(end-start)
# Out:
# 0.18686580657958984

# %%
# Compute the multipoles
plt.figure(figsize=(8,5))

ks, p0g, p2g, p4g = eptdz.compute_redshift_space_power_multipoles(pars,f, Dz=D)
ks, p0, p2, p4 = ept.compute_redshift_space_power_multipoles(pars,f)


plt.plot(ks, -1000*ks,'k--',label='REPT Varying D(z)')
plt.plot(ks, -1000*ks,'k-')

plt.plot(ks, ks*p0,'C0-',label=r'$\ell = 0$')
plt.plot(ks, ks*p0g,'k--')

plt.plot(ks, ks*p2,'C1-',label=r'$\ell = 2$')
plt.plot(ks, ks*p2g,'k--')

plt.plot(ks, ks*p4,'C2-',label=r'$\ell = 4$')
plt.plot(ks, ks*p4g,'k--')

plt.xlabel('k [h/Mpc]')
plt.ylabel(r'$k P_\ell(k)$ [(Mpc/h)$^2$]')

plt.xlim(0,0.25)
plt.ylim(0,1400)

plt.legend(ncol=3,loc='upper right')

plt.show()

# %% [markdown]
# Let's show how we can do many redshifts at once -- we will only very roughly approximate $f(z)$ and $D(z)$ here for simplicity, but they should really be computed more accurately.  We will also assume the same values of the biases, etc., for each sample though of course those are very likely to differ.
#
# ***Note*** how very fast the calculation is for each new redshift.

# %%
plt.figure(figsize=(8,5))
#
icol = 0
for zz in [0.25,0.50,0.75]:
    omz  = 0.3/( 0.3 + 0.7*(1+zz)**(-3)) # A rough approximation to OmegaM(z)
    f    = omz**0.6                      # A rough approximation to f(z)
    D    = 0.6819 * (1.8/(1+zz))         # A *super* rough approximation to D(z).
    # %time ks, p0g, p2g, p4g = eptdz.compute_redshift_space_power_multipoles(pars,f, Dz=D)
    plt.plot(ks,ks*p0g,color='C'+str(icol),label='$z={:.2f}$'.format(zz))
    icol = (icol+1)%10
#
plt.legend(ncol=3,loc='upper right')
#
plt.xlabel('k [h/Mpc]')
plt.ylabel(r'$k P_\ell(k)$ [(Mpc/h)$^2$]')
# Out:
# CPU times: user 3.78 ms, sys: 0 ns, total: 3.78 ms
# Wall time: 3.22 ms
# CPU times: user 2.47 ms, sys: 0 ns, total: 2.47 ms
# Wall time: 2.31 ms
# CPU times: user 2.16 ms, sys: 0 ns, total: 2.16 ms
# Wall time: 2.16 ms
# Text(0, 0.5, '$k P_\\ell(k)$ [(Mpc/h)$^2$]')
